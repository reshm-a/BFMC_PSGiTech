# %%
import numpy as np
a = np.float32([[1,2,3],[2,1,5]]);

# %%
a.shape[:2]
# Out:
# (2, 3)

# %%
# Out:
#   File "C:\Users\2002h\AppData\Local\Temp\ipykernel_11568\428125194.py", line 1
#     a = [0:1,0:2//2]
#           ^
# SyntaxError: invalid syntax

# %%
# importing required libraries
import matplotlib.pyplot as plt
import matplotlib.image as img
  
# reading the image
testImage = img.imread('uu_40.png')
  
# displaying the image
plt.imshow(testImage)
